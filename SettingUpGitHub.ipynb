# %% [markdown]
# # Setting up GitHub on Colab
# https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/ColabNotebooks
# Out:
# /content/gdrive/My Drive/ColabNotebooks

# %%
# %ls -a
# Out:
#  colab-demo/   colab-github-demo.ipynb  'Welcome To Colaboratory'

# %% [markdown]
# Clone an existing github repository into our Drive Colab folder

# %%
#!git clone https://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@github.com/kendrakaiser/colab-demo.git
# Out:
# Cloning into 'colab-demo'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.

# %% [markdown]
# Use the ls command to show all of our files / folders

# %%
# %ls
# Out:
#  colab-demo/               SettingUpGitHub.ipynb
#  colab-github-demo.ipynb  'Welcome To Colaboratory'

# %% [markdown]
# change our directory to the colab-demo directory that we cloned from github

# %%
# %cd colab-demo/
# Out:
# /content/gdrive/My Drive/ColabNotebooks/colab-demo

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	SettingUpGitHub.ipynb
# 	tester.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# set your account's default identity

# %%
 # !git config --global user.email "kendra.kaiser@gmail.com"
 # !git config --global user.name "kendrakaiser"

# %%
# !git add . 
# !git commit -m "first ipynb"
# !git push
# Out:
# [main 6ae93c8] first ipynb
#  2 files changed, 1 insertion(+), 2 deletions(-)
#  rewrite SettingUpGitHub.ipynb (63%)
#  delete mode 100644 setup.ipynb
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
